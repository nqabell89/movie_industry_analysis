# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
genre_runtime_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
genre_runtime_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
studio_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
studio_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
rt_ratings_df = pd.read_csv('zippedData/rt.reviews.tsv.gz', sep='\t', encoding='unicode_escape')
rt_ratings_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
imdb_ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
imdb_ratings_df.rename(columns={'averagerating':'avg_imdb_rating', 'numvotes':'rating_count'}, inplace=True)
imdb_ratings_df.head()
# Out:
#        tconst  avg_imdb_rating  rating_count
# 0  tt10356526              8.3            31
# 1  tt10384606              8.9           559
# 2   tt1042974              6.4            20
# 3   tt1043726              4.2         50352
# 4   tt1060240              6.5            21

# %%
budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
budgets_df['title'] = budgets_df['movie']
budgets_df.drop(columns='movie',inplace=True)
budgets_df['title'].value_counts()
# Out:
#   File "<ipython-input-22-28577093824b>", line 3
#     budgets_df.['title'].value_counts()
#                ^
# SyntaxError: invalid syntax

# %%
budgets_df.head(30)
# Out:
#     id  release_date production_budget domestic_gross worldwide_gross  \
# 0    1  Dec 18, 2009      $425,000,000   $760,507,625  $2,776,345,279
# 1    2  May 20, 2011      $410,600,000   $241,063,875  $1,045,663,875
# 2    3   Jun 7, 2019      $350,000,000    $42,762,350    $149,762,350
# 3    4   May 1, 2015      $330,600,000   $459,005,868  $1,403,013,963
# 4    5  Dec 15, 2017      $317,000,000   $620,181,382  $1,316,721,747
# 5    6  Dec 18, 2015      $306,000,000   $936,662,225  $2,053,311,220
# 6    7  Apr 27, 2018      $300,000,000   $678,815,482  $2,048,134,200
# 7    8  May 24, 2007      $300,000,000   $309,420,425    $963,420,425
# 8    9  Nov 17, 2017      $300,000,000   $229,024,295    $655,945,209
# 9   10   Nov 6, 2015      $300,000,000   $200,074,175    $879,620,923
# 10  11  Jul 20, 2012      $275,000,000   $448,139,099  $1,084,439,099
# 11  12  May 25, 2018      $275,000,000   $213,767,512    $393,151,347
# 12  13   Jul 2, 2013      $275,000,000    $89,302,115    $260,002,115
# 13  14   Mar 9, 2012      $275,000,000    $73,058,679    $282,778,100
# 14  15  Nov 24, 2010      $260,000,000   $200,821,936    $586,477,240
# 15  16   May 4, 2007      $258,000,000   $336,530,303    $894,860,230
# 16  17   May 6, 2016      $250,000,000   $408,084,349  $1,140,069,413
# 17  18  Mar 25, 2016      $250,000,000   $330,360,194    $867,500,281
# 18  19  Dec 14, 2012      $250,000,000   $303,003,568  $1,017,003,568
# 19  20  Jul 15, 2009      $250,000,000   $302,089,278    $935,213,767
# 20  21  Dec 13, 2013      $250,000,000   $258,366,855    $960,366,855
# 21  22  Dec 17, 2014      $250,000,000   $255,119,788    $945,577,621
# 22  23  Apr 14, 2017      $250,000,000   $225,764,765  $1,234,846,267
# 23  24  Jun 28, 2006      $232,000,000   $200,120,000    $374,085,065
# 24  25  May 26, 2017      $230,000,000   $172,558,876    $788,241,137
# 25  26  Nov 14, 2008      $230,000,000   $169,368,427    $591,692,078
# 26  27   May 4, 2012      $225,000,000   $623,279,547  $1,517,935,897
# 27  28   Jul 7, 2006      $225,000,000   $423,315,812  $1,066,215,812
# 28  29  Jun 14, 2013      $225,000,000   $291,045,518    $667,999,518
# 29  30  May 16, 2008      $225,000,000   $141,621,490    $417,341,288
#
#                                                title
# 0                                             Avatar
# 1        Pirates of the Caribbean: On Stranger Tides
# 2                                       Dark Phoenix
# 3                            Avengers: Age of Ultron
# 4                  Star Wars Ep. VIII: The Last Jedi
# 5               Star Wars Ep. VII: The Force Awakens
# 6                             Avengers: Infinity War
# 7         Pirates of the Caribbean: At Worldâs End
# 8                                     Justice League
# 9                                            Spectre
# 10                             The Dark Knight Rises
# 11                           Solo: A Star Wars Story
# 12                                   The Lone Ranger
# 13                                       John Carter
# 14                                           Tangled
# 15                                      Spider-Man 3
# 16                        Captain America: Civil War
# 17                Batman v Superman: Dawn of Justice
# 18                 The Hobbit: An Unexpected Journey
# 19            Harry Potter and the Half-Blood Prince
# 20               The Hobbit: The Desolation of Smaug
# 21         The Hobbit: The Battle of the Five Armies
# 22                           The Fate of the Furious
# 23                                  Superman Returns
# 24  Pirates of the Caribbean: Dead Men Tell No Tales
# 25                                 Quantum of Solace
# 26                                      The Avengers
# 27      Pirates of the Caribbean: Dead Manâs Chest
# 28                                      Man of Steel
# 29          The Chronicles of Narnia: Prince Caspian

# %%
genre_runtime_df['title'] = genre_runtime_df['primary_title']
genre_runtime_df.drop(columns='primary_title', inplace=True)
genre_runtime_df.head()
# Out:
#       tconst              original_title  start_year  runtime_minutes  \
# 0  tt0063540                   Sunghursh        2013            175.0
# 1  tt0066787             Ashad Ka Ek Din        2019            114.0
# 2  tt0069049  The Other Side of the Wind        2018            122.0
# 3  tt0069204             Sabse Bada Sukh        2018              NaN
# 4  tt0100275       La Telenovela Errante        2017             80.0
#
#                  genres                            title
# 0    Action,Crime,Drama                        Sunghursh
# 1       Biography,Drama  One Day Before the Rainy Season
# 2                 Drama       The Other Side of the Wind
# 3          Comedy,Drama                  Sabse Bada Sukh
# 4  Comedy,Drama,Fantasy         The Wandering Soap Opera

# %%
test_df = pd.merge(genre_runtime_df, budgets_df, left_on='title', right_on='title')
test_df.tail(50)
# Out:
#          tconst             original_title  start_year  runtime_minutes  \
# 3765  tt8110640  In the Shadow of the Moon        2019              NaN
# 3766  tt8125482                   Twilight        2018              7.0
# 3767  tt8125482                   Twilight        2018              7.0
# 3768  tt8155288         Happy Death Day 2U        2019            100.0
# 3769  tt8237644                      Flood        2018             60.0
# 3770  tt8259618                Serendipity        2018            107.0
# 3771  tt9654814                Serendipity        2019             74.0
# 3772  tt8266310       Blinded by the Light        2019            117.0
# 3773  tt8325050                   Baby Boy        2017              NaN
# 3774  tt8327616                    Bandits        2018              NaN
# 3775  tt8332280              The Bodyguard        2018             99.0
# 3776  tt8352082                     Undead        2018              NaN
# 3777  tt8383596                    Deok-gu        2018             91.0
# 3778  tt8404256                 Snake Eyes        2020              NaN
# 3779  tt8526282             School of Rock        2018              NaN
# 3780  tt8614260             Without Limits        2018              NaN
# 3781  tt8619504             Without Limits        2018              NaN
# 3782  tt8632862            Fahrenheit 11/9        2018            128.0
# 3783  tt8633120               The Deported        2019              NaN
# 3784  tt8633834            The Bucket List        2018             60.0
# 3785  tt8653640           An Ideal Husband        2018              NaN
# 3786  tt8653840                   Haneshef        2018             97.0
# 3787  tt8655470                Hors normes        2019              NaN
# 3788  tt8662424                Never Again        2017            106.0
# 3789  tt8976472            Ei koskaan enää        2018             69.0
# 3790  tt9379184                Never Again        2014             46.0
# 3791  tt8663516               Child's Play        2019            120.0
# 3792  tt8680254                Richard III        2016              NaN
# 3793  tt8788464                  Mata Hari        2016              NaN
# 3794  tt8824064                     Heroes        2019             88.0
# 3795  tt8870574                     Ransom        2018             98.0
# 3796  tt8890082                 Ghost Town        2018             26.0
# 3797  tt9024106                  Unplanned        2019            106.0
# 3798  tt9087212               Little Voice        2018              NaN
# 3799  tt9095294                Wonder Boys        2018            144.0
# 3800  tt9111170          What Lies Beneath        2018              NaN
# 3801  tt9125468                 Sugar Town        2018             75.0
# 3802  tt9134678                 Invincible        2019              NaN
# 3803  tt9201248         What Just Happened        2018             96.0
# 3804  tt9248762              The Terrorist        2018              NaN
# 3805  tt9268370                       Good        2018             83.0
# 3806  tt9275702                   Salvador        2016             71.0
# 3807  tt9313936                 Stay Alive        2019             72.0
# 3808  tt9448858            The Magic Flute        2010              NaN
# 3809  tt9607270              The Blue Bird        2015             84.0
# 3810  tt9678962                       Fuel        2018              NaN
# 3811  tt9729206                      Diner        2019              NaN
# 3812  tt9805168                    Traitor        2015            110.0
# 3813  tt9844102                        Ray        2018            111.0
# 3814  tt9893078                    Sublime        2019              NaN
#
#                       genres                      title   id  release_date  \
# 3765                Thriller  In the Shadow of the Moon   39   Sep 7, 2007
# 3766             Documentary                   Twilight   89  Nov 21, 2008
# 3767             Documentary                   Twilight   20   Mar 6, 1998
# 3768    Drama,Horror,Mystery         Happy Death Day 2U   78  Feb 13, 2019
# 3769             Documentary                      Flood   66  Dec 31, 2007
# 3770                   Drama                Serendipity   53   Oct 5, 2001
# 3771             Documentary                Serendipity   53   Oct 5, 2001
# 3772  Biography,Comedy,Drama       Blinded by the Light   64  Aug 14, 2019
# 3773                   Drama                   Baby Boy   43  Jun 27, 2001
# 3774                   Drama                    Bandits   59  Oct 12, 2001
# 3775                   Drama              The Bodyguard   68  Nov 25, 1992
# 3776                  Horror                     Undead   81   Jul 1, 2005
# 3777                   Drama                Stand by Me   68   Aug 8, 1986
# 3778        Action,Adventure                 Snake Eyes   78   Aug 7, 1998
# 3779                   Music             School of Rock    6   Oct 3, 2003
# 3780                   Sport             Without Limits   16  Sep 11, 1998
# 3781                     NaN             Without Limits   16  Sep 11, 1998
# 3782             Documentary            Fahrenheit 11/9   29  Sep 21, 2018
# 3783             Documentary               The Deported   62  Dec 31, 2009
# 3784        Adventure,Comedy            The Bucket List   62  Dec 25, 2007
# 3785                  Comedy           An Ideal Husband   23  Jun 18, 1999
# 3786                   Drama                   Flawless   14  Nov 24, 1999
# 3787                  Comedy               The Specials   89  Sep 22, 2000
# 3788                   Drama                Never Again   47  Jul 12, 2002
# 3789       Documentary,Music                Never Again   47  Jul 12, 2002
# 3790                 Romance                Never Again   47  Jul 12, 2002
# 3791                  Horror               Child's Play   77   Nov 9, 1988
# 3792                   Drama                Richard III   65  Dec 29, 1995
# 3793               Biography                  Mata Hari   24  Dec 26, 1931
# 3794             Documentary                     Heroes   12  Oct 24, 2008
# 3795          Drama,Thriller                     Ransom  100   Nov 8, 1996
# 3796     Documentary,History                 Ghost Town   31  Sep 19, 2008
# 3797         Biography,Drama                  Unplanned   33  Mar 29, 2019
# 3798         Horror,Thriller               Little Voice   58   Dec 4, 1998
# 3799          Crime,Thriller                Wonder Boys   13  Feb 23, 2000
# 3800  Drama,Mystery,Thriller          What Lies Beneath   45  Jul 21, 2000
# 3801     Drama,Horror,Sci-Fi                 Sugar Town   82  Sep 17, 1999
# 3802                  Action                 Invincible   27  Aug 25, 2006
# 3803                  Comedy         What Just Happened   16  Oct 17, 2008
# 3804                Thriller              The Terrorist   48  Jan 14, 2000
# 3805             Documentary                       Good   78  Dec 31, 2008
# 3806                   Drama                   Salvador   38  Apr 23, 1986
# 3807             Documentary                 Stay Alive   85  Mar 24, 2006
# 3808                   Music            The Magic Flute   18  Dec 31, 2006
# 3809                   Drama              The Blue Bird   71   Jan 1, 1976
# 3810       Documentary,Sport                       Fuel   35  Nov 14, 2008
# 3811                   Crime                      Diner   11   Apr 2, 1982
# 3812    Action,Drama,Romance                    Traitor   25  Aug 27, 2008
# 3813                   Crime                        Ray    8  Oct 29, 2004
# 3814             Documentary                    Sublime   30  Mar 13, 2007
#
#      production_budget domestic_gross worldwide_gross
# 3765        $2,000,000     $1,134,358      $2,175,587
# 3766       $37,000,000   $192,769,854    $402,280,159
# 3767       $20,000,000    $15,055,091     $15,055,091
# 3768        $9,000,000    $28,051,045     $64,179,495
# 3769       $24,000,000             $0      $4,084,232
# 3770       $28,000,000    $50,255,310     $77,477,297
# 3771       $28,000,000    $50,255,310     $77,477,297
# 3772       $15,000,000             $0              $0
# 3773       $16,000,000    $28,734,552     $28,734,552
# 3774       $75,000,000    $41,523,271     $71,523,271
# 3775       $25,000,000   $121,945,720    $410,899,039
# 3776          $750,000        $41,196        $229,250
# 3777        $8,000,000    $52,287,414     $52,287,414
# 3778       $73,000,000    $55,591,409    $103,891,409
# 3779       $20,000,000    $81,261,177    $131,944,672
# 3780       $25,000,000       $780,326        $780,326
# 3781       $25,000,000       $780,326        $780,326
# 3782        $5,000,000     $6,352,306      $6,653,715
# 3783        $3,000,000             $0              $0
# 3784       $45,000,000    $93,466,502    $174,807,445
# 3785       $10,700,000    $18,542,974     $31,341,183
# 3786       $27,000,000     $4,485,485      $4,485,485
# 3787        $1,000,000        $12,996         $12,996
# 3788          $500,000       $307,631        $308,793
# 3789          $500,000       $307,631        $308,793
# 3790          $500,000       $307,631        $308,793
# 3791        $9,000,000    $33,244,684     $44,196,684
# 3792        $9,200,000     $2,684,904      $4,199,334
# 3793          $558,000       $900,000        $900,000
# 3794          $400,000       $655,538        $655,538
# 3795       $70,000,000   $136,492,681    $308,700,000
# 3796       $20,000,000    $13,367,624     $29,958,228
# 3797        $6,000,000    $18,107,621     $18,107,621
# 3798        $6,000,000     $4,595,000     $21,787,233
# 3799       $35,000,000    $19,389,454     $33,422,485
# 3800       $90,000,000   $155,464,351    $288,693,989
# 3801          $250,000       $178,095        $178,095
# 3802       $40,000,000    $57,806,952     $58,501,127
# 3803       $27,000,000     $1,090,947      $2,412,123
# 3804           $25,000       $195,043        $195,043
# 3805       $16,000,000        $31,631         $31,631
# 3806        $4,500,000     $1,500,000      $1,500,000
# 3807       $20,000,000    $23,086,480     $23,187,506
# 3808       $27,000,000             $0              $0
# 3809        $1,200,000       $887,000        $887,000
# 3810        $2,500,000       $174,255        $174,255
# 3811        $5,000,000    $12,592,907     $12,592,907
# 3812       $22,000,000    $23,530,831     $27,882,226
# 3813       $40,000,000    $75,305,995    $124,823,094
# 3814        $1,800,000             $0              $0

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3815 entries, 0 to 3814
# Data columns (total 11 columns):
# tconst               3815 non-null object
# original_title       3814 non-null object
# start_year           3815 non-null int64
# runtime_minutes      3328 non-null float64
# genres               3743 non-null object
# title                3815 non-null object
# id                   3815 non-null int64
# release_date         3815 non-null object
# production_budget    3815 non-null object
# domestic_gross       3815 non-null object
# worldwide_gross      3815 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 357.7+ KB

# %%
working_df = pd.merge(test_df, imdb_ratings_df, left_on='tconst', right_on='tconst')
working_df.head()
# Out:
#       tconst original_title  start_year  runtime_minutes  \
# 0  tt0249516     Foodfight!        2012             91.0
# 1  tt0326592  The Overnight        2010             88.0
# 2  tt3844362  The Overnight        2015             79.0
# 3  tt0337692    On the Road        2012            124.0
# 4  tt4339118    On the Road        2014             89.0
#
#                     genres          title  id  release_date production_budget  \
# 0  Action,Animation,Comedy     Foodfight!  26  Dec 31, 2012       $45,000,000
# 1                      NaN  The Overnight  21  Jun 19, 2015          $200,000
# 2           Comedy,Mystery  The Overnight  21  Jun 19, 2015          $200,000
# 3  Adventure,Drama,Romance    On the Road  17  Mar 22, 2013       $25,000,000
# 4                    Drama    On the Road  17  Mar 22, 2013       $25,000,000
#
#   domestic_gross worldwide_gross  avg_imdb_rating  rating_count
# 0             $0         $73,706              1.9          8248
# 1     $1,109,808      $1,165,996              7.5            24
# 2     $1,109,808      $1,165,996              6.1         14828
# 3       $720,828      $9,313,302              6.1         37886
# 4       $720,828      $9,313,302              6.0             6
